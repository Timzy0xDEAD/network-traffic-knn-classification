# %% [markdown]
# ## Techniques de transformation des données

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report

# %% [raw]
# Q1. Importer le fichier CSV contenant les données nettoyées.

# %%
dataSet = pd.read_csv("network-traffic-mining\data\processed\dataset_reseau_clean.csv")

# %% [raw]
# Q2. Afficher les 20 premières lignes du dataset afin d'avoir un aperçu de sa structure.

# %%
dataSet.head(20)
# Out:
#    machine_id  os_type  duree_connexion  nombre_requetes  volume_donnees  \
# 0       M1381    Linux       124.841713               80      464.209300
# 1        M996    Linux       203.399243              212      696.590874
# 2       M1411    MacOS        71.099503              213      430.462099
# 3       M1448  Windows       150.118079              216      341.491727
# 4       M1448  Android       182.837035               79      259.873768
# 5        M167  Android       143.479982              224      289.311325
# 6        M127  Windows       113.242452              198      312.953557
# 7       M1247  Android       110.820160              168      679.286073
# 8       M1338  Windows       145.661309              234      424.517234
# 9        M162    MacOS       156.610195              258      601.261817
# 10      M1279  Windows       162.468964              280      492.608417
# 11      M1005    MacOS       165.259168              116      694.718357
# ...

# %% [raw]
# Q3. Afficher les statistiques descriptives des variables numériques afin d'observer les caractéristiques générales des données.

# %%
dataSet.describe()
# Out:
#        duree_connexion  nombre_requetes  volume_donnees
# count     10000.000000      10000.00000    10000.000000
# mean        120.074007        198.82050      499.935969
# std          36.563021         59.30334      139.306894
# min          18.026468         33.00000      112.902668
# 25%          96.162680        158.00000      408.091352
# 50%         120.775692        200.00000      502.638632
# 75%         144.170177        240.00000      589.425863
# max         225.262332        364.00000      892.508398

# %% [raw]
# Q4. Sélectionner les variables numériques du dataset afin de préparer leur transformation.

# %%
dataSet_numeric = dataSet.select_dtypes(include=['number'])

# %% [raw]
# Q5. Appliquer une normalisation des variables numériques.

# %%
scaler = MinMaxScaler()
dataSet_numeric_scaled = pd.DataFrame(
    scaler.fit_transform(dataSet_numeric),
    columns=dataSet_numeric.columns
)

# %% [raw]
# Q6. Créer une nouvelle variable appelée intensite_connexion représentant l'activité du trafic réseau, en combinant les variables nombre_requetes et volume_donnees.

# %%
dataSet['intensite_connexion'] = dataSet['nombre_requetes'] * dataSet['volume_donnees']
dataSet['intensite_connexion'].head()
# Out:
# 0     37136.744008
# 1    147677.265379
# 2     91688.427089
# 3     73762.213040
# 4     20530.027695
# Name: intensite_connexion, dtype: float64

# %% [raw]
# Q7. Transformer la variable catégorielles explicative os_type en variables numérique afin de pouvoir les utiliser dans un modèle de machine learning.

# %%
dataSet = pd.get_dummies(dataSet, columns=['os_type'])
print(dataSet.head())
# Out:
#   machine_id  duree_connexion  nombre_requetes  volume_donnees  \
# 0      M1381       124.841713               80      464.209300
# 1       M996       203.399243              212      696.590874
# 2      M1411        71.099503              213      430.462099
# 3      M1448       150.118079              216      341.491727
# 4      M1448       182.837035               79      259.873768
#
#   statut_connexion  intensite_connexion  os_type_Android  os_type_Linux  \
# 0          success         37136.744008            False           True
# 1          success        147677.265379            False           True
# 2          success         91688.427089            False          False
# 3             fail         73762.213040            False          False
# 4          success         20530.027695             True          False
#
#    os_type_MacOS  os_type_Windows
# 0          False            False
# 1          False            False
# 2           True            False
# ...

# %% [raw]
# Q8. Afficher la structure du dataset après transformation.

# %%
dataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   machine_id           10000 non-null  object
#  1   duree_connexion      10000 non-null  float64
#  2   nombre_requetes      10000 non-null  int64
#  3   volume_donnees       10000 non-null  float64
#  4   statut_connexion     10000 non-null  object
#  5   intensite_connexion  10000 non-null  float64
#  6   os_type_Android      10000 non-null  bool
#  7   os_type_Linux        10000 non-null  bool
#  8   os_type_MacOS        10000 non-null  bool
#  9   os_type_Windows      10000 non-null  bool
# dtypes: bool(4), float64(3), int64(1), object(2)
# memory usage: 507.9+ KB

# %%
dataSet.to_csv("network-traffic-mining\data\processed\dataset_reseau_transformed.csv", index=False)
